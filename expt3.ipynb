# %%
import pandas as pd
import numpy as np

# Load dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Display the shape and first 5 rows of the dataset
print(data.shape)
print(data.head(5))

# Drop unnecessary columns
data = data.drop(columns=["Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15"])

# Handle categorical columns by encoding them
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# Encode binary categorical columns using LabelEncoder
label_encoder = LabelEncoder()
data['Gender'] = label_encoder.fit_transform(data['Gender'])

# Apply OneHotEncoding to non-binary categorical columns like 'Device', 'Day', 'Channel'
# We’ll use a ColumnTransformer to apply OneHotEncoding to the specified columns.
# The rest will remain unchanged (no encoding).

column_transformer = ColumnTransformer(
    transformers=[
        ('device_day_channel', OneHotEncoder(), ['Device', 'Day', 'Channel']),
    ],
    remainder='passthrough'  # Keep other columns as is
)

# Apply the transformation
X = column_transformer.fit_transform(data.iloc[:, :-1])  # All columns except the target column
Y = data.iloc[:, -1].values   # Last column as target

# Split the data into training and testing sets (75% training, 25% testing)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# Feature scaling (standardizing the features)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Train the Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer
age = int(input("Enter New Customer Age: "))
sal = int(input("Enter New Customer Salary: "))
newCust = [[age, sal]]
result = model.predict(sc.transform(newCust))
print(result)

# Output the prediction result
if result == 1:
    print("Customer will Buy")
else:
    print("Customer won't Buy")
# Out:
# (400, 3)
#    Age  Salary  Status
# 0   18   82000       0
# 1   29   80000       0
# 2   47   25000       1
# 3   45   26000       1
# 4   46   28000       1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 12
#       9 print(data.head(5))
#      11 # Drop unnecessary columns
# ---> 12 data = data.drop(columns=["Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15"])
#      14 # Handle categorical columns by encoding them
#      15 from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
# ...

# %%
import pandas as pd
import numpy as np

# Load dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Check and clean column names
print("Column Names:")
print(data.columns)

# Strip spaces from column names (if needed)
data.columns = data.columns.str.strip()

# If 'Channel' is missing or has a different name, update it
# For example, if the 'Channel' column is missing, you could remove it from the transformer
# For now, I'm assuming the 'Device', 'Day', and 'Channel' columns exist. 

# Drop unnecessary columns
data = data.drop(columns=["Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15"])

# Handle categorical columns by encoding them
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# Encode binary categorical columns using LabelEncoder
label_encoder = LabelEncoder()
data['Gender'] = label_encoder.fit_transform(data['Gender'])

# Apply OneHotEncoding to non-binary categorical columns like 'Device', 'Day', 'Channel'
# We’ll use a ColumnTransformer to apply OneHotEncoding to the specified columns.
# The rest will remain unchanged (no encoding).

column_transformer = ColumnTransformer(
    transformers=[
        ('device_day_channel', OneHotEncoder(), ['Device', 'Day', 'Channel']),
    ],
    remainder='passthrough'  # Keep other columns as is
)

# Apply the transformation
X = column_transformer.fit_transform(data.iloc[:, :-1])  # All columns except the target column
Y = data.iloc[:, -1].values   # Last column as target

# Split the data into training and testing sets (75% training, 25% testing)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# Feature scaling (standardizing the features)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Train the Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer
age = int(input("Enter New Customer Age: "))
sal = int(input("Enter New Customer Salary: "))
newCust = [[age, sal]]
result = model.predict(sc.transform(newCust))
print(result)

# Output the prediction result
if result == 1:
    print("Customer will Buy")
else:
    print("Customer won't Buy")
# Out:
# Column Names:
# Index(['Gender', 'Device', 'Day', 'First_timer?', 'Channel ', 'Min_spent',
#        'Clicks ', 'Country', 'Annual_inc', 'Age', 'Purchased ', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 51
#      49 # Feature scaling (standardizing the features)
#      50 sc = StandardScaler()
# ---> 51 X_train = sc.fit_transform(X_train)
#      52 X_test = sc.transform(X_test)
#      54 # Train the Logistic Regression model
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
# ...

# %%
import pandas as pd
import numpy as np

# Load dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Display the shape and first 5 rows of the dataset
print("Dataset Shape:", data.shape)
print("First 5 Rows of Data:")
print(data.head(5))

# Check for missing values or non-numeric data
print("Check for missing values or non-numeric data:")
print(data.info())

# Separate features (X) and target (Y)
X = data.iloc[:, :-1]  # Features (all columns except last one)
Y = data.iloc[:, -1]   # Target (last column)

# Convert categorical columns to numeric using one-hot encoding (if necessary)
# Check which columns are of type object (categorical)
categorical_columns = X.select_dtypes(include=['object']).columns

# Apply one-hot encoding for categorical columns (convert to dummy variables)
X = pd.get_dummies(X, columns=categorical_columns, drop_first=True)

# Now we can safely apply scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Apply scaling only to numeric columns
X_scaled = sc.fit_transform(X)  # This scales all numeric features

# Split the data into training and testing sets (75% training, 25% testing)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.25, random_state=0)

# Train the Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer with validation on the input
while True:
    try:
        age = int(input("Enter New Customer Age: "))
        sal = int(input("Enter New Customer Salary: "))
        if age <= 0 or sal <= 0:
            print("Age and Salary should be positive values. Please try again.")
            continue
        newCust = [[age, sal]]
        
        # Apply scaling to the new customer input (same scaling as for training data)
        newCust_scaled = sc.transform(newCust)
        
        result = model.predict(newCust_scaled)
        print("Prediction Result:", result)

        # Output the prediction result
        if result == 1:
            print("Customer will Buy")
        else:
            print("Customer won't Buy")
        break  # Break the loop once valid inputs are given
    except ValueError:
        print("Invalid input! Please enter valid numbers for Age and Salary.")
# Out:
# Dataset Shape: (10999, 16)
# First 5 Rows of Data:
#     Cust_ID  Gender  Device  First_timer?          Channel   Day  Min_spent  \
# 0  J#58032A    male      PC           1.0  Social media ads  FRI        4.0
# 1  Z#51384I    male  Mobile           1.0     Google search  WED        2.0
# 2  T#46862G  female      PC           0.0             Other  FRI        7.0
# 3  M#33554V    male  Mobile           1.0     Google search  TUE        5.0
# 4  X#92545O    male  Mobile           1.0  Social media ads  SAT        9.0
#
#    Clicks   Annual_inc  Country   Age  Purchased   Unnamed: 12  Unnamed: 13  \
# 0     21.0     40000.0    India  41.0           0          NaN          NaN
# 1     17.0     40000.0    China  32.0           0          NaN          NaN
# 2     20.0     35000.0    Japan  58.0           1          NaN          NaN
# 3     15.0     35000.0   Canada  54.0           0          NaN          NaN
# 4     19.0     10000.0  Ireland  55.0           1          NaN          NaN
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# Load dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Display the shape and first 5 rows of the dataset
print("Dataset Shape:", data.shape)
print("First 5 Rows of Data:")
print(data.head(5))

# Check for missing values
print("Check for missing values:")
print(data.isnull().sum())

# Separate features (X) and target (Y)
X = data.iloc[:, :-1]  # Features (all columns except last one)
Y = data.iloc[:, -1]   # Target (last column)

# Handle missing values (impute with mean for numerical columns)
imputer = SimpleImputer(strategy='mean')  # Using 'mean' to impute missing values
X = imputer.fit_transform(X)

# Now we can safely apply scaling
sc = StandardScaler()

# Apply scaling only to numeric columns
X_scaled = sc.fit_transform(X)

# Split the data into training and testing sets (75% training, 25% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.25, random_state=0)

# Train the Logistic Regression model
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix and accuracy
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer with validation on the input
while True:
    try:
        age = int(input("Enter New Customer Age: "))
        sal = int(input("Enter New Customer Salary: "))
        if age <= 0 or sal <= 0:
            print("Age and Salary should be positive values. Please try again.")
            continue
        newCust = [[age, sal]]
        
        # Apply scaling to the new customer input (same scaling as for training data)
        newCust_scaled = sc.transform(newCust)
        
        result = model.predict(newCust_scaled)
        print("Prediction Result:", result)

        # Output the prediction result
        if result == 1:
            print("Customer will Buy")
        else:
            print("Customer won't Buy")
        break  # Break the loop once valid inputs are given
    except ValueError:
        print("Invalid input! Please enter valid numbers for Age and Salary.")
# Out:
# Dataset Shape: (10999, 16)
# First 5 Rows of Data:
#    Gender  Device  Day  First_timer?          Channel   Min_spent  Clicks   \
# 0    male      PC  FRI           1.0  Social media ads        4.0     21.0
# 1    male  Mobile  WED           1.0     Google search        2.0     17.0
# 2  female      PC  FRI           0.0             Other        7.0     20.0
# 3    male  Mobile  TUE           1.0     Google search        5.0     15.0
# 4    male  Mobile  SAT           1.0  Social media ads        9.0     19.0
#
#    Country  Annual_inc   Age  Purchased   Unnamed: 11  Unnamed: 12  \
# 0    India     40000.0  41.0           0          NaN          NaN
# 1    China     40000.0  32.0           0          NaN          NaN
# 2    Japan     35000.0  58.0           1          NaN          NaN
# 3   Canada     35000.0  54.0           0          NaN          NaN
# 4  Ireland     10000.0  55.0           1          NaN          NaN
#
#    Unnamed: 13  Unnamed: 14 Unnamed: 15
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# Load dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Display the shape and first 5 rows of the dataset
print("Dataset Shape:", data.shape)
print("First 5 Rows of Data:")
print(data.head(5))

# Check for missing values
print("Check for missing values:")
print(data.isnull().sum())

# Separate features (X) and target (Y)
X = data.iloc[:, :-1]  # Features (all columns except last one)
Y = data.iloc[:, -1]   # Target (last column)

# Handle missing values (impute with mean for numerical columns)
imputer = SimpleImputer(strategy='mean')  # Using 'mean' to impute missing values
X = imputer.fit_transform(X)

# Now we can safely apply scaling
sc = StandardScaler()

# Apply scaling only to numeric columns
X_scaled = sc.fit_transform(X)

# Split the data into training and testing sets (75% training, 25% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.25, random_state=0)

# Train the Logistic Regression model
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix and accuracy
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer with validation on the input
while True:
    try:
        age = int(input("Enter New Customer Age: "))
        sal = int(input("Enter New Customer Salary: "))
        if age <= 0 or sal <= 0:
            print("Age and Salary should be positive values. Please try again.")
            continue
        newCust = [[age, sal]]
        
        # Apply scaling to the new customer input (same scaling as for training data)
        newCust_scaled = sc.transform(newCust)
        
        result = model.predict(newCust_scaled)
        print("Prediction Result:", result)

        # Output the prediction result
        if result == 1:
            print("Customer will Buy")
        else:
            print("Customer won't Buy")
        break  # Break the loop once valid inputs are given
    except ValueError:
        print("Invalid input! Please enter valid numbers for Age and Salary.")
# Out:
# Dataset Shape: (10999, 16)
# First 5 Rows of Data:
#    Gender  Device  Day  First_timer?          Channel   Min_spent  Clicks   \
# 0    male      PC  FRI           1.0  Social media ads        4.0     21.0
# 1    male  Mobile  WED           1.0     Google search        2.0     17.0
# 2  female      PC  FRI           0.0             Other        7.0     20.0
# 3    male  Mobile  TUE           1.0     Google search        5.0     15.0
# 4    male  Mobile  SAT           1.0  Social media ads        9.0     19.0
#
#    Country  Annual_inc   Age  Purchased   Unnamed: 11  Unnamed: 12  \
# 0    India     40000.0  41.0           0          NaN          NaN
# 1    China     40000.0  32.0           0          NaN          NaN
# 2    Japan     35000.0  58.0           1          NaN          NaN
# 3   Canada     35000.0  54.0           0          NaN          NaN
# 4  Ireland     10000.0  55.0           1          NaN          NaN
#
#    Unnamed: 13  Unnamed: 14 Unnamed: 15
# ...

# %%
import pandas as pd
import numpy as np

# Load the dataset
data = pd.read_csv("DigitalAd_dataset.csv")

# Print the shape and first 5 rows of the dataset to understand its structure
print(data.shape)
print(data.head(5))

# Separate features (X) and target (Y)
X = data.iloc[:, :-1].values  # All columns except the last one (features)
Y = data.iloc[:, -1].values   # Last column as target

# Split the data into training and testing sets (75% training, 25% testing)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# Feature scaling (standardizing the features)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Train a Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)

# Print the accuracy of the model
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred) * 100))

# Predict for a new customer
age = int(input("Enter New Customer Age: "))
sal = int(input("Enter New Customer Salary: "))
newCust = [[age, sal]]

# Output the prediction result
result = model.predict(sc.transform(newCust))
print(result)

if result == 1:
    print("Customer will Buy")
else:
    print("Customer won't Buy")
# Out:
# (400, 3)
#    Age  Salary  Status
# 0   18   82000       0
# 1   29   80000       0
# 2   47   25000       1
# 3   45   26000       1
# 4   46   28000       1
# Confusion Matrix:
# [[61  0]
#  [20 19]]
# Accuracy of the Model: 80.0%
# Enter New Customer Age:  45
# Enter New Customer Salary:  45000
# [0]
# Customer won't Buy
